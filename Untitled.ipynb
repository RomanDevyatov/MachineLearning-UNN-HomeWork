# %% [markdown]
# Подключение модулей:

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns
import sklearn

# %% [markdown]
# #0 Задача классификации Постановка задачи. Х - множество объектов. Y - конечное множество меток. Метки можем пронумеровать.
#
# Если Y = {0, 1}, то задача бинарной классификации. Если dimY > 2, то просто задача классификации.
#
# Дополнительно, есть входная выборка D = {(Xi, Yi), Xi из X, Yi из Y, i = 1..N}, на которой мы будем обучаться проставлять метки.
#
# Например, фотография собаки может классифицироваться как собака с вероятностью 0.99 и как кошка с вероятностью 0.01 Нам нужно знать условное распределение этой случайной величины на этом объекте p(y|x)
#
# Определение: Задача нахождения p(y|x) при данном множестве меток Y и данном наборе размеченных примеров D = {(Xi, Yi), Xi из X, Yi из Y, i = 1..N} называется задачей классификации.
#
# Этот датасет содержит информацию о разных винах

# %%
def harmonize_data(passengers):
        
    return passengers

# %% [markdown]
# 1. Загружаем данные

# %%
#1 creates dadtaframes
test = pd.read_csv('../input/airline-passenger-satisfaction/test.csv')
train = pd.read_csv('../input/airline-passenger-satisfaction/train.csv')
train
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# 5                5  111157  Female     Loyal Customer   26  Personal Travel
# 6                6   82113    Male     Loyal Customer   47  Personal Travel
# 7                7   96462  Female     Loyal Customer   52  Business travel
# 8                8   79485  Female     Loyal Customer   41  Business travel
# 9                9   65725    Male  disloyal Customer   20  Business travel
# 10              10   34991  Female  disloyal Customer   24  Business travel
# ...

# %%
#2
del train['Unnamed: 0']
del train['id']

train.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  103904.000000    103904.000000          103904.000000
# mean       39.379706      1189.448375               2.729683
# std        15.114964       997.147281               1.327829
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       843.000000               3.000000
# 75%        51.000000      1743.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      103904.000000           103904.000000
# mean                            3.060296                2.756901
# std                             1.525075                1.398929
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# ...

# %%
train.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
train.tail() # посмотрим первые пять наблюдений
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 103899              192                      2
# 103900             2347                      4
# 103901             1995                      1
# 103902             1000                      1
# 103903             1723                      1
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 103899                                  1                       2
# 103900                                  4                       4
# 103901                                  1                       1
# ...

# %%
train.corr() # посмотрим матрицу корреляции
# Out:
#                                         Age  Flight Distance  \
# Age                                1.000000         0.099461
# Flight Distance                    0.099461         1.000000
# Inflight wifi service              0.017859         0.007131
# Departure/Arrival time convenient  0.038125        -0.020043
# Ease of Online booking             0.024842         0.065717
# Gate location                     -0.001330         0.004793
# Food and drink                     0.023000         0.056994
# Online boarding                    0.208939         0.214869
# Seat comfort                       0.160277         0.157333
# Inflight entertainment             0.076444         0.128740
# On-board service                   0.057594         0.109526
# Leg room service                   0.040583         0.133916
# Baggage handling                  -0.047529         0.063184
# Checkin service                    0.035482         0.073072
# ...

# %% [markdown]
# 3. Обработка пропущенных значений

# %%
#3
train.isna().sum()
# myData.isna().sum()
# myData.fillna(myData.median(axis = 0), axis=0, inplace=True)
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
train["Arrival Delay in Minutes"] = train["Arrival Delay in Minutes"].fillna(train["Arrival Delay in Minutes"].median())
train.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
#4
train.at[train['Gender'] =='Male','Gender'] = 0
train.at[train['Gender'] == 'Female', 'Gender'] = 1

train.at[train['Type of Travel'] == 'Personal Travel', 'Type of Travel'] = 0
train.at[train['Type of Travel'] == 'Business travel', 'Type of Travel'] = 1

train.at[train['satisfaction'] == 'neutral or dissatisfied', 'satisfaction'] = 0
train.at[train['satisfaction'] == 'satisfied', 'satisfaction'] = 1

train.at[train['Class'] == 'Eco', 'Class'] = 0
train.at[train['Class'] == 'Eco Plus', 'Class'] = 1
train.at[train['Class'] == 'Business', 'Class'] = 2

train.at[train['Customer Type'] == 'disloyal Customer', 'Customer Type'] = 0
train.at[train['Customer Type'] == 'Loyal Customer', 'Customer Type'] = 1

train.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              1   13               0      1              460
# 1       0              0   25               1      2              235
# 2       1              1   26               1      2             1142
# 3       1              1   25               1      2              562
# 4       0              1   61               1      2              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
# myData['country'].fillna(myData['country'].mode().iloc[0], inplace=True)
# myData['designation'].fillna(myData['designation'].mode().iloc[0], inplace=True)
# myData['province'].fillna(myData['province'].mode().iloc[0], inplace=True)
# myData['region_1'].fillna(myData['region_1'].mode().iloc[0], inplace=True)
# myData['region_2'].fillna(myData['region_2'].mode().iloc[0], inplace=True)
# myData['taster_name'].fillna(myData['taster_name'].mode().iloc[0], inplace=True)
# myData['taster_twitter_handle'].fillna(myData['taster_twitter_handle'].mode().iloc[0], inplace=True)
# myData['variety'].fillna(myData['variety'].mode().iloc[0], inplace=True)

# %%
#myData.isna().sum()

# %%
#4
# myData['country'] = myData['country'].astype('category')
# myData['description'] = myData['description'].astype('category')
# myData['designation'] = myData['designation'].astype('category')
# myData['province'] = myData['province'].astype('category')
# myData['region_1'] = myData['region_1'].astype('category')
# myData['region_2'] = myData['region_2'].astype('category')
# myData['taster_name'] = myData['taster_name'].astype('category')
# myData['taster_twitter_handle'] = myData['taster_twitter_handle'].astype('category')
# myData['title'] = myData['title'].astype('category')
# myData['variety'] = myData['variety'].astype('category')
# myData['winery'] = myData['winery'].astype('category')

# %%
# plt.scatter(myData['price'], myData['points'], color = np.array(('b', 'r')) alpha = 0.5)
# plt.xlabel('price')
# plt.ylabel('points')

# %%
#5
features = ['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
       'Flight Distance', 'Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']
target = ['satisfaction']

X_train = train[features]
y_train = train[target].to_numpy()
X_test = test[features]
y_test = test[target].to_numpy()

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %% [markdown]
# 6. Разбить данные на обучающую и тестовую выборки

# %%
#6
from sklearn.model_selection import train_test_split

#train, test = train_test_split(myData, test_size=0.2)
#

# %%
#7

# %%
#7
y=train["satisfaction"]
x=train.drop(columns=["satisfaction"])
min_k = 1
max_k = 15
scores_train = []
scores_test = []
for k in range(min_k,max_k + 1):
    knc = KNeighborsClassifier(n_neighbors = k)
    knc.fit(x, y)
    scores_train.append(knc.score(x,y))

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(10, 5))

ax[0].set_title("train")
ax[0].plot(range(min_k,max_k + 1),scores_train)
ax[0].grid(True)
plt.show()
